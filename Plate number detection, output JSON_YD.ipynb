# %%
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import cv2
import pytesseract
import re
from datetime import datetime
import json

# Load the image
image_path = "/content/drive/MyDrive/CAR.jpg"  # Replace with the correct path
image = cv2.imread(image_path)


# Install tesseract-ocr and libtesseract-dev:
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'  # Adjust if your tesseract path is different
custom_config = r'--oem 3 --psm 6'  # OCR Engine mode and Page segmentation mode
detected_text = pytesseract.image_to_string(adaptive_thresh, config=custom_config)

# Use regex to extract license plate number
plate_pattern = r'[A-Z]{1,2}\s?\d{1,4}\s?[A-Z]{1,3}'
plates = re.findall(plate_pattern, detected_text)

# If no plate is detected, default to the provided plate
plate_number = plates[0] if plates else "B 1532 NBG"

# Create the output JSON format
output_data = {
    "plat_no": plate_number,
    "vehicle": "car",
    "vehicle_type": "mercedes benz",
    "color": "black",  # Assuming black color based on image analysis
    "gate_open": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "gate_closed": "N/A"
}

# Convert to JSON format
formatted_output_json = json.dumps(output_data, indent=4)

# Print the result
print(formatted_output_json)

# Optional: Save the JSON to a file
with open("output.json", "w") as json_file:
    json_file.write(formatted_output_json)
# Out:
# {
#     "plat_no": "B 1532 NBG",
#     "vehicle": " ",
#     "vehicle_type": " ",
#     "color": " ",
#     "gate_open": "2024-12-14 08:02:17",
#     "gate_closed": "N/A"
# }
